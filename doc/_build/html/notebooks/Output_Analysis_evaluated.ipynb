# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import os, sys
import seaborn as sns

# %matplotlib inline

# %%
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})

# %%
path = os.path.realpath(os.path.dirname('__file__'))
if 'notebooks' not in path:
    path = os.path.join(path, 'notebooks')
path
data = pd.read_csv(os.path.join(path, 'uncertainties_testing.csv'), usecols=["um.pedsPerHourOff","um.pedsPerHourOn"])

# %%
data = data.dropna()
data.head()
# Out:
#    um.pedsPerHourOff  um.pedsPerHourOn
# 1         998.979592        539.795918
# 3         447.959184       1427.551020
# 5         937.755102        509.183673
# 7         203.061224        723.469388
# 9        1274.489796        937.755102

# %%
sns.kdeplot(data['um.pedsPerHourOff'], shade=True);
sns.kdeplot(data['um.pedsPerHourOn'], shade=True);
